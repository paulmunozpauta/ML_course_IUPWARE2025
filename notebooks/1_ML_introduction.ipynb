# %% [markdown]
# # Clone the repository and switch to the IUPWARE_2025 branch

# %% [markdown]
# Step 1

# %%
# !git clone --branch IUPWARE_2025 https://github.com/paulmunozpauta/Course_ML_hydrological_forecasting.git
# Out:
# Cloning into 'Course_ML_hydrological_forecasting'...
# remote: Enumerating objects: 757, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 757 (delta 85), reused 127 (delta 51), pack-reused 589 (from 1)
# Receiving objects: 100% (757/757), 1.08 GiB | 20.83 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# Updating files: 100% (440/440), done.

# %% [markdown]
# Step 2

# %%
ls
# Out:
# Course_ML_hydrological_forecasting/  sample_data/

# %%
# %cd Course_ML_hydrological_forecasting
# Out:
# /content/Course_ML_hydrological_forecasting

# %%
ls
# Out:
# LICENSE  notebooks/  poetry.lock  pyproject.toml  README.md

# %% [markdown]
# Step 3

# %%
# Install Poetry
# !pip install poetry
# Disable virtual environment creation (needed for Colab)
# !poetry config virtualenvs.create false
# Out:
# Collecting poetry
#   Downloading poetry-2.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting build<2.0.0,>=1.2.1 (from poetry)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: cachecontrol<0.15.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (0.14.2)
# Collecting cleo<3.0.0,>=2.1.0 (from poetry)
#   Downloading cleo-2.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting dulwich<0.23.0,>=0.22.6 (from poetry)
#   Downloading dulwich-0.22.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from poetry) (2.21.1)
# Collecting findpython<0.7.0,>=0.6.2 (from poetry)
#   Downloading findpython-0.6.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting installer<0.8.0,>=0.7.0 (from poetry)
#   Downloading installer-0.7.0-py3-none-any.whl.metadata (936 bytes)
# Collecting keyring<26.0.0,>=25.1.0 (from poetry)
#   Downloading keyring-25.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.11/dist-packages (from poetry) (24.2)
# Collecting pbs-installer<2026.0.0,>=2025.1.6 (from pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry)
#   Downloading pbs_installer-2025.2.12-py3-none-any.whl.metadata (991 bytes)
# Collecting pkginfo<2.0,>=1.12 (from poetry)
#   Downloading pkginfo-1.12.1.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: platformdirs<5,>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from poetry) (4.3.6)
# Collecting poetry-core==2.1.1 (from poetry)
#   Downloading poetry_core-2.1.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyproject-hooks<2.0.0,>=1.0.0 (from poetry)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: requests<3.0,>=2.26 in /usr/local/lib/python3.11/dist-packages (from poetry) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from poetry) (1.0.0)
# Requirement already satisfied: shellingham<2.0,>=1.5 in /usr/local/lib/python3.11/dist-packages (from poetry) (1.5.4)
# Collecting tomlkit<1.0.0,>=0.11.4 (from poetry)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting trove-classifiers>=2022.5.19 (from poetry)
#   Downloading trove_classifiers-2025.2.18.16-py3-none-any.whl.metadata (2.3 kB)
# Collecting virtualenv<21.0.0,>=20.26.6 (from poetry)
#   Downloading virtualenv-20.29.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol<0.15.0,>=0.14.0->cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (1.1.0)
# Requirement already satisfied: filelock>=3.8.0 in /usr/local/lib/python3.11/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (3.17.0)
# Collecting crashtest<0.5.0,>=0.4.1 (from cleo<3.0.0,>=2.1.0->poetry)
#   Downloading crashtest-0.4.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from cleo<3.0.0,>=2.1.0->poetry)
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.11/dist-packages (from dulwich<0.23.0,>=0.22.6->poetry) (2.3.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/lib/python3/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/lib/python3/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (0.7.1)
# Requirement already satisfied: importlib_metadata>=4.11.4 in /usr/local/lib/python3.11/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (8.6.1)
# Collecting jaraco.classes (from keyring<26.0.0,>=25.1.0->poetry)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring<26.0.0,>=25.1.0->poetry)
#   Downloading jaraco.functools-4.1.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.context (from keyring<26.0.0,>=25.1.0->poetry)
#   Downloading jaraco.context-6.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: httpx<1,>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (0.28.1)
# Requirement already satisfied: zstandard>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.26->poetry) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.26->poetry) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.26->poetry) (2025.1.31)
# Collecting distlib<1,>=0.3.7 (from virtualenv<21.0.0,>=20.26.6->poetry)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.11.4->keyring<26.0.0,>=25.1.0->poetry) (3.21.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from jaraco.classes->keyring<26.0.0,>=25.1.0->poetry) (10.6.0)
# Collecting backports.tarfile (from jaraco.context->keyring<26.0.0,>=25.1.0->poetry)
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (1.3.1)
# Downloading poetry-2.1.1-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.7/277.7 kB 5.9 MB/s eta 0:00:00
# Downloading poetry_core-2.1.1-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.2/331.2 kB 12.0 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading cleo-2.1.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 4.4 MB/s eta 0:00:00
# Downloading dulwich-0.22.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (979 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.7/979.7 kB 30.6 MB/s eta 0:00:00
# Downloading findpython-0.6.2-py3-none-any.whl (20 kB)
# Downloading installer-0.7.0-py3-none-any.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 21.7 MB/s eta 0:00:00
# Downloading keyring-25.6.0-py3-none-any.whl (39 kB)
# Downloading pbs_installer-2025.2.12-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.1 MB/s eta 0:00:00
# Downloading pkginfo-1.12.1.1-py3-none-any.whl (32 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading trove_classifiers-2025.2.18.16-py3-none-any.whl (13 kB)
# Downloading virtualenv-20.29.2-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 39.6 MB/s eta 0:00:00
# Downloading crashtest-0.4.1-py3-none-any.whl (7.6 kB)
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 19.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.2 MB/s eta 0:00:00
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco.context-6.0.1-py3-none-any.whl (6.8 kB)
# Downloading jaraco.functools-4.1.0-py3-none-any.whl (10 kB)
# Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Installing collected packages: trove-classifiers, distlib, virtualenv, tomlkit, rapidfuzz, pyproject-hooks, poetry-core, pkginfo, pbs-installer, jaraco.functools, jaraco.classes, installer, findpython, dulwich, crashtest, backports.tarfile, jaraco.context, cleo, build, keyring, poetry
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# Successfully installed backports.tarfile-1.2.0 build-1.2.2.post1 cleo-2.1.0 crashtest-0.4.1 distlib-0.3.9 dulwich-0.22.7 findpython-0.6.2 installer-0.7.0 jaraco.classes-3.4.0 jaraco.context-6.0.1 jaraco.functools-4.1.0 keyring-25.6.0 pbs-installer-2025.2.12 pkginfo-1.12.1.1 poetry-2.1.1 poetry-core-2.1.1 pyproject-hooks-1.2.0 rapidfuzz-3.12.1 tomlkit-0.13.2 trove-classifiers-2025.2.18.16 virtualenv-20.29.2

# %% [markdown]
# Step 4

# %%
# !poetry install --no-root
# Out:
# Skipping virtualenv creation, as specified in config file.
# Installing dependencies from lock file
#
# Package operations: 29 installs, 58 updates, 0 removals
#
#   - Downgrading attrs (25.1.0 -> 24.2.0): Pending...
#   - Installing pyrsistent (0.19.3): Pending...
#   - Updating traitlets (5.7.1 -> 5.9.0): Pending...
#   - Installing pyrsistent (0.19.3): Pending...
#   - Updating traitlets (5.7.1 -> 5.9.0): Pending...
#   - Downgrading attrs (25.1.0 -> 24.2.0): Downloading... 0%
#   - Installing pyrsistent (0.19.3): Pending...
#   - Updating traitlets (5.7.1 -> 5.9.0): Pending...
#   - Updating traitlets (5.7.1 -> 5.9.0): Pending...
#   - Installing pyrsistent (0.19.3): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.9.0): Pending...
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 0%
#   - Installing pyrsistent (0.19.3): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 0%
#   - Downgrading attrs (25.1.0 -> 24.2.0): Downloading... 100%
#   - Installing pyrsistent (0.19.3): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 0%
#   - Installing pyrsistent (0.19.3): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 0%
#   - Downgrading attrs (25.1.0 -> 24.2.0): Installing...
#   - Installing pyrsistent (0.19.3): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 0%
#   - Installing pyrsistent (0.19.3): Downloading... 100%
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.9.0): Downloading... 100%
#   - Updating traitlets (5.7.1 -> 5.9.0): Installing...
#   - Updating traitlets (5.7.1 -> 5.9.0): Installing...
#   - Installing pyrsistent (0.19.3): Installing...
#   - Updating traitlets (5.7.1 -> 5.9.0): Installing...
#   - Updating traitlets (5.7.1 -> 5.9.0): Installing...
#   - Installing pyrsistent (0.19.3)
#   - Updating traitlets (5.7.1 -> 5.9.0): Installing...
#   - Updating traitlets (5.7.1 -> 5.9.0)
#   - Installing pyrsistent (0.19.3)
#   - Updating traitlets (5.7.1 -> 5.9.0)
#   - Downgrading attrs (25.1.0 -> 24.2.0)
#   - Installing pyrsistent (0.19.3)
#   - Updating traitlets (5.7.1 -> 5.9.0)
#   - Downgrading jsonschema (4.23.0 -> 4.17.3): Pending...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jsonschema (4.23.0 -> 4.17.3): Downloading... 0%
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Downloading... 0%
#   - Downgrading pycparser (2.22 -> 2.21): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 0%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 0%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Downloading... 100%
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 0%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Downloading... 100%
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 0%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jsonschema (4.23.0 -> 4.17.3): Downloading... 100%
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Downloading... 100%
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 0%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 100%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 100%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Installing...
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 100%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Installing...
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 100%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading jsonschema (4.23.0 -> 4.17.3): Installing...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Installing...
#   - Downgrading pycparser (2.22 -> 2.21): Downloading... 100%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading pycparser (2.22 -> 2.21): Installing...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Downloading... 0%
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Downloading... 0%
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Downloading... 0%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Downloading... 100%
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Downloading... 0%
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Downloading... 0%
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0): Installing...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Pending...
#   - Downgrading tornado (6.4.2 -> 6.2): Downloading... 0%
#   - Downgrading tornado (6.4.2 -> 6.2): Downloading... 100%
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Downloading... 0%
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Downloading... 100%
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Updating pyzmq (24.0.1 -> 26.2.0): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0)
#   - Updating pyzmq (24.0.1 -> 26.2.0): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Installing...
#   - Downgrading pycparser (2.22 -> 2.21): Installing...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0)
#   - Updating pyzmq (24.0.1 -> 26.2.0): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Downgrading jsonschema (4.23.0 -> 4.17.3)
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0): Installing...
#   - Downgrading pycparser (2.22 -> 2.21): Installing...
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0)
#   - Updating pyzmq (24.0.1 -> 26.2.0): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2)
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0)
#   - Updating pyzmq (24.0.1 -> 26.2.0): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2)
#   - Downgrading pycparser (2.22 -> 2.21)
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0)
#   - Updating pyzmq (24.0.1 -> 26.2.0): Installing...
#   - Downgrading tornado (6.4.2 -> 6.2)
#   - Downgrading tornado (6.4.2 -> 6.2)
#   - Updating pyzmq (24.0.1 -> 26.2.0)
#   - Downgrading tornado (6.4.2 -> 6.2)
#   - Downgrading pycparser (2.22 -> 2.21)
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0)
#   - Updating pyzmq (24.0.1 -> 26.2.0)
#   - Downgrading tornado (6.4.2 -> 6.2)
#   - Downgrading jupyter-core (5.7.2 -> 4.12.0)
#   - Downgrading pycparser (2.22 -> 2.21)
#   - Updating python-dateutil (2.8.2 -> 2.9.0.post0)
#   - Updating pyzmq (24.0.1 -> 26.2.0)
#   - Downgrading tornado (6.4.2 -> 6.2)
#   - Downgrading cffi (1.17.1 -> 1.15.1): Pending...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Pending...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Pending...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Pending...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Downloading... 0%
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Pending...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 0%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Downloading... 100%
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Installing...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Installing...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading cffi (1.17.1 -> 1.15.1): Downloading... 0%
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Installing...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Downloading... 0%
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Pending...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Downloading... 0%
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Downloading... 0%
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Downloading... 100%
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Downloading... 0%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Downloading... 100%
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Downloading... 100%
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Installing...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Downloading... 100%
#   - Downgrading soupsieve (2.6 -> 2.4.1): Installing...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Installing...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Installing...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Installing...
#   - Downgrading cffi (1.17.1 -> 1.15.1): Downloading... 100%
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Installing...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Installing...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Installing...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Installing...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Installing...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Installing...
#   - Downgrading cffi (1.17.1 -> 1.15.1): Installing...
#   - Updating jupyter-client (6.1.12 -> 7.4.9): Installing...
#   - Downgrading markupsafe (3.0.2 -> 2.1.5): Installing...
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Downgrading markupsafe (3.0.2 -> 2.1.5)
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Downgrading markupsafe (3.0.2 -> 2.1.5)
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Updating jupyter-client (6.1.12 -> 7.4.9)
#   - Downgrading markupsafe (3.0.2 -> 2.1.5)
#   - Downgrading nbformat (5.10.4 -> 5.8.0): Installing...
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Downgrading nbformat (5.10.4 -> 5.8.0)
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Updating jupyter-client (6.1.12 -> 7.4.9)
#   - Downgrading markupsafe (3.0.2 -> 2.1.5)
#   - Downgrading nbformat (5.10.4 -> 5.8.0)
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Downgrading cffi (1.17.1 -> 1.15.1)
#   - Updating jupyter-client (6.1.12 -> 7.4.9)
#   - Downgrading markupsafe (3.0.2 -> 2.1.5)
#   - Downgrading nbformat (5.10.4 -> 5.8.0)
#   - Downgrading soupsieve (2.6 -> 2.4.1)
#   - Installing arrow (1.2.3): Pending...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Pending...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Pending...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Pending...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Pending...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Downloading... 0%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Downloading... 0%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Installing arrow (1.2.3): Downloading... 0%
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Downloading... 0%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Downloading... 100%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Downloading... 100%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Installing arrow (1.2.3): Downloading... 100%
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Downloading... 100%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Installing arrow (1.2.3): Installing...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Downloading... 100%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Installing...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Pending...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading bleach (6.2.0 -> 6.0.0): Downloading... 0%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Pending...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Downloading... 0%
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Downloading... 100%
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 0%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Downloading... 100%
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Installing...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Downloading... 0%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Installing arrow (1.2.3)
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3): Installing...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Downloading... 0%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0): Pending...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Downloading... 100%
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0): Pending...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0): Pending...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Installing...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0): Pending...
#   - Downgrading packaging (24.2 -> 24.0): Downloading... 0%
#   - Downgrading packaging (24.2 -> 24.0): Downloading... 100%
#   - Downgrading packaging (24.2 -> 24.0): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2)
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0): Installing...
#   - Downgrading pygments (2.18.0 -> 2.17.2): Pending...
#   - Downgrading pygments (2.18.0 -> 2.17.2): Downloading... 0%
#   - Downgrading pygments (2.18.0 -> 2.17.2): Downloading... 100%
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Pending...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Downloading... 0%
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Downloading... 100%
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading bleach (6.2.0 -> 6.0.0): Installing...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2)
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading beautifulsoup4 (4.13.3 -> 4.12.3)
#   - Downgrading bleach (6.2.0 -> 6.0.0): Installing...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2)
#   - Downgrading nbclient (0.10.2 -> 0.7.4): Installing...
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading nbclient (0.10.2 -> 0.7.4)
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading mistune (3.1.1 -> 3.0.2)
#   - Downgrading nbclient (0.10.2 -> 0.7.4)
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2)
#   - Downgrading mistune (3.1.1 -> 3.0.2)
#   - Downgrading nbclient (0.10.2 -> 0.7.4)
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2)
#   - Downgrading mistune (3.1.1 -> 3.0.2)
#   - Downgrading nbclient (0.10.2 -> 0.7.4)
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading bleach (6.2.0 -> 6.0.0)
#   - Downgrading jupyterlab-pygments (0.3.0 -> 0.2.2)
#   - Downgrading mistune (3.1.1 -> 3.0.2)
#   - Downgrading nbclient (0.10.2 -> 0.7.4)
#   - Downgrading packaging (24.2 -> 24.0)
#   - Downgrading pygments (2.18.0 -> 2.17.2): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1): Installing...
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1)
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1)
#   - Downgrading pygments (2.18.0 -> 2.17.2)
#   - Downgrading tinycss2 (1.4.0 -> 1.2.1)
#   - Updating decorator (4.4.2 -> 5.1.1): Pending...
#   - Installing fqdn (1.5.1): Pending...
#   - Installing isoduration (20.11.0): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Installing fqdn (1.5.1): Pending...
#   - Installing isoduration (20.11.0): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Updating decorator (4.4.2 -> 5.1.1): Downloading... 0%
#   - Installing fqdn (1.5.1): Pending...
#   - Installing isoduration (20.11.0): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Installing isoduration (20.11.0): Downloading... 0%
#   - Installing jedi (0.19.2): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Installing isoduration (20.11.0): Downloading... 0%
#   - Installing jedi (0.19.2): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Installing fqdn (1.5.1): Downloading... 0%
#   - Installing isoduration (20.11.0): Downloading... 0%
#   - Installing jedi (0.19.2): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Installing fqdn (1.5.1): Downloading... 0%
#   - Installing isoduration (20.11.0): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Updating decorator (4.4.2 -> 5.1.1): Downloading... 100%
#   - Installing fqdn (1.5.1): Downloading... 0%
#   - Installing isoduration (20.11.0): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing isoduration (20.11.0): Downloading... 100%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing fqdn (1.5.1): Downloading... 0%
#   - Installing isoduration (20.11.0): Downloading... 100%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Updating decorator (4.4.2 -> 5.1.1): Installing...
#   - Installing fqdn (1.5.1): Downloading... 0%
#   - Installing isoduration (20.11.0): Downloading... 100%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing isoduration (20.11.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing isoduration (20.11.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing fqdn (1.5.1): Downloading... 100%
#   - Installing isoduration (20.11.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing isoduration (20.11.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing fqdn (1.5.1): Installing...
#   - Installing isoduration (20.11.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing isoduration (20.11.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Installing fqdn (1.5.1)
#   - Installing isoduration (20.11.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Downloading... 0%
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Downloading... 100%
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 0%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 100%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 100%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Installing isoduration (20.11.0)
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Downloading... 100%
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Installing jedi (0.19.2): Downloading... 90%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Downloading... 0%
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Downloading... 100%
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Installing jedi (0.19.2): Downloading... 100%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Downloading... 0%
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Downloading... 0%
#   - Installing jedi (0.19.2): Installing...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Downloading... 0%
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Downloading... 100%
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Installing...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Installing...
#   - Installing jedi (0.19.2)
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Installing...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3339-validator (0.1.4): Downloading... 0%
#   - Installing rfc3339-validator (0.1.4): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Installing...
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing rfc3986-validator (0.1.1): Downloading... 0%
#   - Installing rfc3986-validator (0.1.1): Downloading... 100%
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Pending...
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Downloading... 0%
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Downloading... 100%
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Installing...
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0)
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Installing...
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Pending...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Downloading... 0%
#   - Downgrading terminado (0.18.1 -> 0.17.1): Downloading... 100%
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Downgrading nbconvert (7.16.6 -> 7.6.0)
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Installing...
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6)
#   - Downgrading nbconvert (7.16.6 -> 7.6.0)
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48): Installing...
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing uri-template (1.3.0): Downloading... 0%
#   - Installing uri-template (1.3.0): Downloading... 100%
#   - Installing uri-template (1.3.0): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Pending...
#   - Downgrading webcolors (24.11.1 -> 1.13): Downloading... 0%
#   - Downgrading webcolors (24.11.1 -> 1.13): Downloading... 100%
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Pending...
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Pending...
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1)
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Pending...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Downloading... 0%
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Downloading... 100%
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Installing fqdn (1.5.1)
#   - Installing isoduration (20.11.0)
#   - Installing jedi (0.19.2)
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6)
#   - Downgrading nbconvert (7.16.6 -> 7.6.0)
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1)
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Updating decorator (4.4.2 -> 5.1.1)
#   - Installing fqdn (1.5.1)
#   - Installing isoduration (20.11.0)
#   - Installing jedi (0.19.2)
#   - Downgrading matplotlib-inline (0.1.7 -> 0.1.6)
#   - Downgrading nbconvert (7.16.6 -> 7.6.0)
#   - Downgrading prometheus-client (0.21.1 -> 0.17.1)
#   - Downgrading prompt-toolkit (3.0.50 -> 3.0.48)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Downgrading setuptools (75.1.0 -> 68.0.0): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Downgrading setuptools (75.1.0 -> 68.0.0)
#   - Downgrading terminado (0.18.1 -> 0.17.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Downgrading webcolors (24.11.1 -> 1.13)
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13)
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Downgrading terminado (0.18.1 -> 0.17.1)
#   - Installing uri-template (1.3.0)
#   - Downgrading webcolors (24.11.1 -> 1.13)
#   - Downgrading websocket-client (1.8.0 -> 1.6.1): Installing...
#   - Downgrading websocket-client (1.8.0 -> 1.6.1)
#   - Downgrading debugpy (1.8.0 -> 1.7.0): Pending...
#   - Updating psutil (5.9.5 -> 6.1.1): Pending...
#   - Installing python-json-logger (3.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Updating psutil (5.9.5 -> 6.1.1): Pending...
#   - Installing python-json-logger (3.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading debugpy (1.8.0 -> 1.7.0): Downloading... 0%
#   - Updating psutil (5.9.5 -> 6.1.1): Pending...
#   - Installing python-json-logger (3.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Updating psutil (5.9.5 -> 6.1.1): Pending...
#   - Installing python-json-logger (3.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading debugpy (1.8.0 -> 1.7.0): Downloading... 100%
#   - Updating psutil (5.9.5 -> 6.1.1): Pending...
#   - Installing python-json-logger (3.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Updating psutil (5.9.5 -> 6.1.1): Pending...
#   - Installing python-json-logger (3.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading debugpy (1.8.0 -> 1.7.0): Installing...
#   - Updating psutil (5.9.5 -> 6.1.1): Pending...
#   - Installing python-json-logger (3.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Installing python-json-logger (3.0.1): Downloading... 0%
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Installing python-json-logger (3.0.1): Downloading... 100%
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Installing python-json-logger (3.0.1): Installing...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Installing python-json-logger (3.0.1)
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Pending...
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Downloading... 0%
#   - Installing python-json-logger (3.0.1)
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Downloading... 0%
#   - Updating psutil (5.9.5 -> 6.1.1): Downloading... 0%
#   - Installing python-json-logger (3.0.1)
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Downloading... 0%
#   - Installing python-json-logger (3.0.1)
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Downloading... 0%
#   - Updating psutil (5.9.5 -> 6.1.1): Downloading... 100%
#   - Installing python-json-logger (3.0.1)
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Downloading... 0%
#   - Installing python-json-logger (3.0.1)
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Downloading... 0%
#   - Updating psutil (5.9.5 -> 6.1.1): Installing...
#   - Installing python-json-logger (3.0.1)
#   - Downgrading pyyaml (6.0.2 -> 6.0.1): Downloading... 0%
# ...
#   - Installing jupyterlab (3.6.8): Downloading... 100%
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Downloading... 100%
#   - Installing fiona (1.9.6): Downloading... 80%
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Downloading... 100%
#   - Installing jupyterlab (3.6.8): Installing...
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Installing...
#   - Installing fiona (1.9.6): Downloading... 90%
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Installing...
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Installing...
#   - Installing fiona (1.9.6): Downloading... 100%
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Installing...
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Installing...
#   - Installing fiona (1.9.6): Installing...
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Installing...
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3): Pending...
#   - Installing rasterio (1.4.3): Downloading... 0%
#   - Installing rasterio (1.4.3): Downloading... 10%
#   - Installing rasterio (1.4.3): Downloading... 20%
#   - Installing rasterio (1.4.3): Downloading... 30%
#   - Installing rasterio (1.4.3): Downloading... 40%
#   - Installing rasterio (1.4.3): Downloading... 50%
#   - Installing rasterio (1.4.3): Downloading... 60%
#   - Installing rasterio (1.4.3): Downloading... 70%
#   - Installing rasterio (1.4.3): Downloading... 80%
#   - Installing rasterio (1.4.3): Downloading... 90%
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3): Downloading... 90%
#   - Installing fiona (1.9.6)
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3): Downloading... 90%
#   - Updating scipy (1.13.1 -> 1.15.1): Pending...
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 0%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 10%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 10%
#   - Installing rasterio (1.4.3): Downloading... 100%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 10%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 20%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 20%
#   - Installing rasterio (1.4.3): Installing...
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 20%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 30%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 40%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 50%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 60%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 70%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 80%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 90%
#   - Updating scipy (1.13.1 -> 1.15.1): Downloading... 100%
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Pending...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Downloading... 0%
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Downloading... 100%
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2)
#   - Updating jupyter-console (6.1.0 -> 6.6.3): Installing...
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Pending...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Downloading... 0%
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Downloading... 100%
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Installing...
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Installing...
#   - Updating jupyter-console (6.1.0 -> 6.6.3)
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Installing...
#   - Installing fiona (1.9.6)
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2)
#   - Updating jupyter-console (6.1.0 -> 6.6.3)
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Installing...
#   - Downgrading et-xmlfile (2.0.0 -> 1.1.0)
#   - Installing fiona (1.9.6)
#   - Updating ipywidgets (7.7.1 -> 8.1.5): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2)
#   - Updating jupyter-console (6.1.0 -> 6.6.3)
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Installing...
#   - Downgrading joblib (1.4.2 -> 1.3.2)
#   - Updating jupyter-console (6.1.0 -> 6.6.3)
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Installing...
#   - Updating ipywidgets (7.7.1 -> 8.1.5)
#   - Downgrading joblib (1.4.2 -> 1.3.2)
#   - Updating jupyter-console (6.1.0 -> 6.6.3)
#   - Installing jupyterlab (3.6.8)
#   - Installing rasterio (1.4.3)
#   - Updating scipy (1.13.1 -> 1.15.1): Installing...
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0): Installing...
#   - Downgrading xarray (2025.1.2 -> 2023.12.0)
#   - Downgrading xarray (2025.1.2 -> 2023.12.0)
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0)
#   - Downgrading xarray (2025.1.2 -> 2023.12.0)
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0)
#   - Downgrading xarray (2025.1.2 -> 2023.12.0)
#   - Updating scipy (1.13.1 -> 1.15.1)
#   - Downgrading threadpoolctl (3.5.0 -> 3.1.0)
#   - Downgrading xarray (2025.1.2 -> 2023.12.0)
#   - Installing descartes (1.1.0): Pending...
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Pending...
#   - Installing jupyter (1.1.1): Pending...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Pending...
#   - Installing rioxarray (0.15.7): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Pending...
#   - Installing rioxarray (0.15.7): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Pending...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 0%
#   - Installing rioxarray (0.15.7): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing rioxarray (0.15.7): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Pending...
#   - Installing jupyter (1.1.1): Pending...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing descartes (1.1.0): Downloading... 0%
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Pending...
#   - Installing jupyter (1.1.1): Pending...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Pending...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing rioxarray (0.15.7): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing jupyter (1.1.1): Pending...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 0%
#   - Installing jupyter (1.1.1): Pending...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing jupyter (1.1.1): Downloading... 0%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing jupyter (1.1.1): Downloading... 100%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 0%
#   - Installing jupyter (1.1.1): Downloading... 100%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing descartes (1.1.0): Downloading... 100%
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 0%
#   - Installing jupyter (1.1.1): Downloading... 100%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing jupyter (1.1.1): Installing...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 0%
#   - Installing jupyter (1.1.1): Installing...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing descartes (1.1.0): Installing...
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 0%
#   - Installing jupyter (1.1.1): Installing...
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Downloading... 100%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing rioxarray (0.15.7): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 0%
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Installing descartes (1.1.0)
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 0%
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 0%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Downloading... 100%
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Downloading... 100%
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading geopandas (1.0.1 -> 0.14.4): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2)
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2)
#   - Downgrading geopandas (1.0.1 -> 0.14.4)
#   - Installing jupyter (1.1.1)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3): Installing...
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2)
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2)
#   - Downgrading openpyxl (3.1.5 -> 3.1.3)
#   - Installing rioxarray (0.15.7)
#   - Downgrading seaborn (0.13.2 -> 0.12.2)

# %% [markdown]
# Now let's start wit the hands-on course

# %% [markdown]
# <div style="text-align:center;">
#     <img style="width: 30%;" src="https://github.com/paulmunozpauta/Course_ML_hydrological_forecasting/blob/IUPWARE_2025/notebooks/static/imgs/Logo_course.png?raw=1">
#     <p style="margin-top:10px;">paul.andres.munoz@gmail.com<br>paul.munoz@vub.be</p>
# </div>
#
#
# # Part 1. Introduction to Machine Learning for Water and Climate
#
# In this session, we will:
#
# - Explore the basics Machine Learning (ML).
# - Understand when and what for we should use ML.
# - Explore some applications of ML in Water and Climate.
# - Learn about some types of ML algorithms.
# - Discuss ML challenges for hydrological and climate applications.

# %% [markdown]
# ## What is Machine Learning (ML)?
#
# Machine Learning (ML) is about **programming computers to learn from data** .
#
# > [Arthur Samuel] ML is the field of study that gives computers the ability to **learn without being explicitly programmed**.
#
# Something more formal:
#
# > [Tom Mitchell] A computer program is said to learn from experience $E$ with respect to some task $T$ and some performance measure $P$, if its performance on $T$, as measured by $P$, improves with experience $E$.
#
# In water and climate:
#
# > Machine Learning (ML) is a branch of artificial intelligence (AI) that focuses on developing algorithms and data-driven statistical models that enable computers to learn and make predictions or decisions based on data.
#
# > ML algorithms produce models capable of extracting patterns and making predictions from data, without being explicitly programmed for a specific task.

# %% [markdown]
# ## Why use Machine Learning?
#
# When we build systems that do not rely on ML, we generally follow these steps:
#
# 1. Conceptualization (we define rules).
# 2. Write an algorithm (equations) to meet 1.
# 3. If the algorithm works well, we implement it. If not, we return to step 1.
#
# However, if the problem is complex, we are likely to end up with a long list of rules that are difficult to follow and challenging to apply to other similar problems. Here, a ML model would be much shorter, easier to maintain, and, in many cases, more accurate.
#
# With ML, we can simply train an algorithm on a large dataset and then inspect the algorithm's `feature importance` to better understand the relationship between the data and the problem. This process is known as data mining.

# %% [markdown]
# ## Some applications of Machine Learning:
#
# ML has numerous applications, and here are some of the most notable in hydrology and climatology:
#
# - `Image Classification`: Typically performed using convolutional neural networks (CNNs).
#
# > Classifying satellite images to detect water bodies, glaciers, and deforested areas. For instance, NASA’s Earth Observatory uses ML to classify land cover types and monitor drought conditions.
#
# - `Semantic Segmentation`: The algorithm is trained to classify each pixel in an image, such as detecting brain tumors.
#
# > Using ML to identify flooded areas from satellite imagery after extreme rainfall events. Agencies like Copernicus Emergency Management Service apply ML-based segmentation for disaster response.
#
# - `Natural Language Processing` (NLP): Specifically, text classification, which can be learned using recurrent neural networks (RNNs), CNNs, or Transformers.
#
# > In weather forecasting, this could be used to analyze and classify weather reports and climate-related news.
#
# - Chatbots: Involve many NLP tasks, such as Natural Language Understanding (NLU) and Question Answering.
#
# > AI-powered water management assistants provide real-time flood monitoring and early warning alerts. Governments and NGOs deploy ML-powered chatbots to disseminate flood risk information.
#
# - `Voice Recognition`: Detects and processes speech/audio signals using RNNs, CNNs, or Transformers.
#
# > Field researchers use speech-to-text AI to record and transcribe weather station observations for hydrological field studies.
#
# - `Anomaly Detection`: Can be solved using supervised learning (classification) or unsupervised learning (anomaly detection).
#
# > Detecting sensor failures or false readings in real-time flood monitoring stations. Anomaly detection methods help identify sudden water level changes that indicate flash floods.
#
# - `Clustering`: Segmenting customers based on their purchases to design more effective targeted marketing campaigns.
#
# > Identifying hydrological regions with similar rainfall-runoff characteristics. Water management authorities use clustering to group catchments with similar flood risks.
#
# - `Dimensionality Reduction`: Used for visualizing high-dimensional data with methods like Principal Component Analysis (PCA) and T-SNE.
#
# > Analyzing multi-variable climate datasets (e.g., temperature, precipitation, humidity, wind speed) to identify dominant climate patterns.

# %% [markdown]
# ## Main types of Machine Learning systems
#
# ML algorithms can be classified based on the level of supervision they receive during training.
# These methods play a crucial role in forecasting, risk assessment, and decision-making.
#
# ### 1. Supervised Learning
#
# In supervised learning, the algorithm is trained on a dataset that contains both input data and labeled target values. It aims to map inputs to the correct outputs based on historical data.
#
# Used for:
# #### Classification (discrete predictions)
#
# With classification, we aim to predict discrete values. Some examples include:
#
# **Precipitation event classification**
#
# >Predicting whether an upcoming weather event will be light rain, a thunderstorm, or heavy rainfall. Crucial for flood management and early warning systems.
#
# **Water quality classification**
#
# >Classifying water samples as potable or non-potable based on contamination levels, helping water management agencies ensure safe drinking water.
#
# **Flood risk classification**
#
# >Assessing flood-prone areas based on river flow, topography, soil moisture, and precipitation data. Used in disaster preparedness programs.
#
# **Climate type classification**
#
# >Clustering regions into categories like tropical, subtropical, or arid based on long-term weather data, useful for agriculture and urban planning.
#
# #### Regression (continuous predictions)
#
# On the other hand, regression deals with continuous target values. Examples include:
#
# - **River flow prediction**: Regression is used to predict river flow based on historical precipitation, temperature, and geographic characteristics.
# - **Groundwater level modeling**: Regression models can predict groundwater levels based on recharge, extraction, and other hydrological variables.
# - **Evapotranspiration prediction**: Regression is used to predict the amount of water that evaporates and transpires based on solar radiation, temperature, and humidity.
# - **Temperature regression**: Regression is used to predict daily maximum and minimum temperatures based on historical weather data, such as solar radiation, altitude, and latitude.
# - **Precipitation prediction**: Regression algorithms can predict the amount of precipitation in a region based on prior climate data, such as wind patterns and sea temperatures.
#
# Some regression-based models are also used for classification, such as `Logistic Regression`, which outputs a probability $\in [0,1]$. Popular supervised learning algorithms include:
#
# - K-Nearest Neighbors
# - Linear Regression
# - Logistic Regression
# - Decision Trees and Random Forests
# - Neural Networks
# - Naive Bayes

# %% [markdown]
# ### 2. Unsupervised learning
#
# The model is trained on unlabeled data and tries to find hidden patterns or groupings in the dataset. Used for clustering, anomaly detection, and dimensionality reduction. Some unsupervised learning algorithms include:
#
# - **Clustering**:
#   - **K-Means**:
#     > K-Means can group geographic regions based on similar climate patterns. This can help identify areas with comparable climates and facilitate agricultural planning and water resource management.
#   - **DBSCAN**:
#     > DBSCAN can identify areas of high concentration of heavy rainfall events in a dataset of precipitation records, which is crucial for identifying flood-prone zones.
#   - **Hierarchical clustering**:
#     > Hierarchical clustering organizes geographic regions into a tree of clusters based on climate similarities. This helps classify and understand climate patterns at different spatial scales.
#
# - **Anomaly Detection**:
#   - **One-Class SVM**:
#     > One-Class SVM detects anomalies in river water level time series, identifying unusual events like flash floods or severe droughts.
#   - **Isolation Forest**:
#     > Isolation Forest identifies outliers in climate datasets, which could indicate extreme weather events, such as exceptional heatwaves or extreme cold events.
#   - **Autoencoders**:
#     > Autoencoders detect anomalous patterns in water quality records, identifying unusual changes in water composition that could signal contamination issues.
#
# - **Dimensionality Reduction**: The goal is to compress data without losing too much information (e.g., combining highly correlated features).
#   - **Principal Component Analysis (PCA)**:
#     > PCA is commonly used to reduce the dimensionality of multivariate climate data, simplifying the analysis of complex climate patterns and visualizing data.
#   - **Kernel PCA**:
#     > Kernel PCA reduces the dimensionality of climate data using nonlinear kernel functions, useful for highly nonlinear climate datasets like global temperature patterns.
#   - **T-SNE**:
#     > T-SNE is used to visualize river flow time series data in a two-dimensional space, making it easier to identify temporal patterns and trends in hydrological data.
#
# - **Association Rule Learning**:
#   - **Apriori**:
#     > Apriori can uncover interesting associations between climate variables, such as the relationship between temperature and relative humidity across different regions.
#   - **Eclat**:
#     > Eclat identifies relationships in hydrogeological data, such as the association between soil permeability and aquifer recharge in specific areas.

# %% [markdown]
# ### Other interesting concepts
#
# - **Batch Learning**: Models are trained on all available data at once, then deployed to make predictions without being updated with new data. Suitable for static historical datasets.
#
# Example:
# > Historical water levels and precipitation data are used to train a flood prediction model once. The model is deployed for real-time predictions but cannot update with new data.
#
# - **Online Learning**: Models are trained incrementally as data arrives, adapting to new information over time. Suitable for systems receiving continuous data streams.
#
# Example:
# > A weather forecasting model continuously updates its predictions with real-time temperature, humidity, and pressure measurements. This ensures forecasts adapt to changing weather conditions.
#
# - **Instance-Based Learning**: Predictions are made by comparing new data points to historical data based on similarity.
#
# Example:
# > For water quality monitoring, new measurements are compared to historical data from similar conditions (e.g., geography, climate) to predict quality.
#
# - **Model-Based Learning**: Predictions are made using a trained model that captures complex relationships within the data.
#
# Example:
# > A climate prediction model uses variables like temperature, humidity, and pressure to forecast future weather patterns, relying on learned relationships rather than direct comparisons to historical data.

# %% [markdown]
# ## Lets start with the basics
# Import required libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
import sklearn.linear_model
import matplotlib.dates as mdates

# %% [markdown]
# Read runoff and precipitation data

# %%
root_directory = os.getcwd()
print(root_directory)
# Out:
# /content/Course_ML_hydrological_forecasting

# %%
data_path = os.path.join(root_directory, "notebooks/data/Hourly_runoff.xlsx")
print(data_path)
# Out:
# /content/Course_ML_hydrological_forecasting/notebooks/data/Hourly_runoff.xlsx

# %%
Hourly_runoff = pd.read_excel(data_path)

# %%
Hourly_runoff.head(5)
# Out:
#                  Date Runoff (m3/s)
# 0 2018-01-08 00:59:00      0.495995
# 1 2018-01-08 01:59:00      0.490064
# 2 2018-01-08 02:59:00       0.48541
# 3 2018-01-08 03:59:00       0.47294
# 4 2018-01-08 04:59:00      0.470238

# %%
Hourly_runoff['Date'] = Hourly_runoff.Date.apply(lambda x: pd.to_datetime(x,dayfirst=False))
Hourly_runoff.set_index(Hourly_runoff['Date'],inplace=True)
Hourly_runoff = Hourly_runoff.drop(columns=['Date'])

# %%
Hourly_runoff['Runoff (m3/s)'] = pd.to_numeric(Hourly_runoff['Runoff (m3/s)'], errors='coerce')
Hourly_runoff
# Out:
#                      Runoff (m3/s)
# Date
# 2018-01-08 00:59:00       0.495995
# 2018-01-08 01:59:00       0.490064
# 2018-01-08 02:59:00       0.485410
# 2018-01-08 03:59:00       0.472940
# 2018-01-08 04:59:00       0.470238
# ...                            ...
# 2020-12-28 04:59:00       6.242112
# 2020-12-28 05:59:00       6.165206
# 2020-12-28 06:59:00       6.106803
# 2020-12-28 07:59:00       6.053304
# 2020-12-28 08:59:00       5.902995
#
# [26021 rows x 1 columns]

# %%
Hourly_runoff.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
root_directory
# Out:
# '/content/Course_ML_hydrological_forecasting'

# %%
fig, ax = plt.subplots()
Hourly_runoff.plot(ax=ax)
plt.ylabel('Runoff ($m^3/s$)')
plt.xlabel('')
plt.legend().set_visible(False)
save_path = os.path.join(root_directory, "notebooks/figures")
os.makedirs(save_path, exist_ok=True)
plt.tight_layout()
plt.savefig(os.path.join(save_path, 'Runoff_plot.png'), format='png', dpi =300)

# %%
data_path = os.path.join(root_directory, "notebooks/data/Hourly_precipitation.csv")
print(data_path)
Hourly_pcp = pd.read_csv(data_path)
Hourly_pcp
# Out:
# /content/Course_ML_hydrological_forecasting/notebooks/data/Hourly_precipitation.csv
#       Date_yy/mm/dd_hh:mm:ss  tip_corrected_mm  \
# 0        2012-09-27 12:00:00          0.108980
# 1        2012-09-27 13:00:00          4.904100
# 2        2012-09-27 14:00:00          2.724500
# 3        2012-09-27 15:00:00          2.179600
# 4        2012-09-27 16:00:00          0.544900
# ...                      ...               ...
# 80971    2021-12-23 07:00:00          0.111362
# 80972    2021-12-23 08:00:00          0.000000
# 80973    2021-12-23 09:00:00          0.000000
# 80974    2021-12-23 10:00:00          0.000000
# 80975    2021-12-23 11:00:00               NaN
#
#        Cumulated_precipitation_Texas_mm
# 0                              0.108980
# 1                              5.013080
# 2                              7.737580
# 3                              9.917180
# 4                             10.462080
# ...                                 ...
# 80971                      10424.182458
# 80972                      10424.182458
# 80973                      10424.182458
# 80974                      10424.182458
# 80975                               NaN
#
# [80976 rows x 3 columns]

# %%
Hourly_pcp = Hourly_pcp.rename(columns={'Date_yy/mm/dd_hh:mm:ss': 'Date'})
Hourly_pcp['Date'] = Hourly_pcp.Date.apply(lambda x: pd.to_datetime(x,dayfirst=False))
Hourly_pcp = Hourly_pcp.drop(columns=['Cumulated_precipitation_Texas_mm'])
Hourly_pcp
# Out:
#                      Date  tip_corrected_mm
# 0     2012-09-27 12:00:00          0.108980
# 1     2012-09-27 13:00:00          4.904100
# 2     2012-09-27 14:00:00          2.724500
# 3     2012-09-27 15:00:00          2.179600
# 4     2012-09-27 16:00:00          0.544900
# ...                   ...               ...
# 80971 2021-12-23 07:00:00          0.111362
# 80972 2021-12-23 08:00:00          0.000000
# 80973 2021-12-23 09:00:00          0.000000
# 80974 2021-12-23 10:00:00          0.000000
# 80975 2021-12-23 11:00:00               NaN
#
# [80976 rows x 2 columns]

# %%
Hourly_pcp.set_index(Hourly_pcp['Date'],inplace=True)
Hourly_pcp = Hourly_pcp.drop(columns=['Date'])
Hourly_pcp['tip_corrected_mm'] = pd.to_numeric(Hourly_pcp['tip_corrected_mm'], errors='coerce')
Hourly_pcp = Hourly_pcp.sort_index()
Hourly_pcp.head(6)
# Out:
#                      tip_corrected_mm
# Date
# 2012-09-27 12:00:00           0.10898
# 2012-09-27 13:00:00           4.90410
# 2012-09-27 14:00:00           2.72450
# 2012-09-27 15:00:00           2.17960
# 2012-09-27 16:00:00           0.54490
# 2012-09-27 17:00:00           4.35920

# %%
fig, ax = plt.subplots()
Hourly_pcp.plot(ax=ax)
plt.ylabel('Hourly precipitation ($mm$)')
plt.legend().set_visible(False)
plt.tight_layout()
save_path = os.path.join(root_directory, "notebooks/figures")
os.makedirs(save_path, exist_ok=True)
plt.savefig(os.path.join(save_path, 'Precipitation_plot.png'), format='png', dpi =300)

# %%
fig, ax = plt.subplots()
Hourly_pcp.loc['2020'].cumsum().plot(ax=ax)
plt.ylabel('Accumulated precipitation ($mm$)')
plt.legend().set_visible(False)
plt.tight_layout()
save_path = os.path.join(root_directory, "notebooks/figures")
os.makedirs(save_path, exist_ok=True)
plt.savefig(os.path.join(save_path, 'Cumulated_precipitation.png'), format='png', dpi =300)

# %%
Hourly_runoff.index = Hourly_runoff.index.round(freq='h')
Hourly_pcp.index = Hourly_pcp.index.round(freq='h')
Hourly_data = pd.concat([Hourly_runoff, Hourly_pcp],axis=1, join='outer')
Hourly_data
# Out:
#                      Runoff (m3/s)  tip_corrected_mm
# Date
# 2012-09-27 12:00:00            NaN          0.108980
# 2012-09-27 13:00:00            NaN          4.904100
# 2012-09-27 14:00:00            NaN          2.724500
# 2012-09-27 15:00:00            NaN          2.179600
# 2012-09-27 16:00:00            NaN          0.544900
# ...                            ...               ...
# 2021-12-23 07:00:00            NaN          0.111362
# 2021-12-23 08:00:00            NaN          0.000000
# 2021-12-23 09:00:00            NaN          0.000000
# 2021-12-23 10:00:00            NaN          0.000000
# 2021-12-23 11:00:00            NaN               NaN
#
# [80976 rows x 2 columns]

# %%
start_analysis='2018'
end_analysis='2020'
fig,ax = plt.subplots()
plt.ylim(ymax=300)
ax2 = ax.twinx()
plt.ylim(ymax=50)
ax.plot(Hourly_data['Runoff (m3/s)'][start_analysis:end_analysis],color='red',label='Precipitation')
ax2.plot(Hourly_data['tip_corrected_mm'][start_analysis:end_analysis],color='blue',label='Runoff')
plt.gca().invert_yaxis()
ax.legend(loc=(0.05,0.55))
ax2.legend(loc=(0.4,0.55))
ax.set_ylabel('Hourly runoff ($m^3/s$)')
ax2.set_ylabel('Hourly precipitation (mm)')
ax2.set_xlabel('Date')
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_minor_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.tight_layout()
save_path = os.path.join(root_directory, "notebooks/figures")
os.makedirs(save_path, exist_ok=True)
plt.savefig(os.path.join(save_path, 'Precipitation_vs_runoff.png'), format='png', dpi =300)

# %%
# Train a Linear Model
Hourly_data = Hourly_data.dropna()
X = Hourly_data['tip_corrected_mm'][Hourly_data['tip_corrected_mm']>0].to_numpy()
X_reshaped = X.reshape(-1, 1)
Y = Hourly_data['Runoff (m3/s)'][Hourly_data['tip_corrected_mm']>0].to_numpy()
Y_reshaped = Y.reshape(-1, 1)
model = sklearn.linear_model.LinearRegression()

# %%
# Train the Model
model.fit(X_reshaped,Y_reshaped)
# Out:
# LinearRegression()

# %%
X_new = [[20]]
print(model.predict(X_new))
# Out:
# [[26.42417757]]

# %%
# let's visualize our model, because it's a linear one, we can plot it using two points
X = [[0], [20]]
y_hat = model.predict(X)

# %%
# Visualize Data
Hourly_data[Hourly_data['tip_corrected_mm']>0].plot(kind='scatter', x='tip_corrected_mm', y='Runoff (m3/s)', xlim=(0, 20), ylim=(0,200))
plt.plot(X, y_hat, c='red')
plt.show()

# %% [markdown]
# Is a linear model sufficient to describe precipitation-runoff relations?

# %% [markdown]
# In summary, we follow these steps to implement a machine learning algorithm:
#
# 1. Study the data and process the information.
# 2. Select the model.
# 3. Train the model.
# 4. Make inferences using the model.

# %% [markdown]
# ### Main Challenges of ML for Water and Climate and Climate Forecasting
#
# 1. Poor data quality.
# 2. Selecting the appropiate learning algorithm.
#
# #### Data
#
# - It has been demonstrated that many algorithms, from the simplest to the most complex, perform relatively similarly when provided with sufficient data.
# - Therefore, greater effort is suggested in ML algorithm development or **feature engineering**.
# - The training dataset may not be representative of the overall data distribution. This creates problems for effective generalization. For example:
#   - If the training dataset is too small, it will suffer from sampling noise.
#   - Even large samples can be unrepresentative if the sampling method is flawed, a problem known as **sampling bias**.
# - Hydrological and climate data can vary significantly over time and space. Selecting the appropriate scale for modeling is crucial.
# - Low-quality data is also a major challenge. Accurate data on precipitation, temperature, streamflow, and other parameters is essential. Inaccurate data can lead to incorrect results and poor decisions (especially if the measurements of the target variable are unreliable!).
# - Training data filled with outliers, errors, and noise makes it harder for the algorithm to detect underlying patterns, resulting in a poor model. Meteorological and hydrological station records may also have missing values or measurement errors that must be addressed effectively.
# - Additionally, datasets may contain irrelevant features (predictors). The system will only learn effectively if the data includes many relevant features and few irrelevant ones. A critical success factor for ML projects is **feature engineering**, which involves creating features that result in a quality model.
#
# #### Feature Selection and Engineering
#
# Feature selection and engineering are particularly important in this context:
#
# - **Climate and Hydrology Relevance**: Identifying the most relevant climatic and hydrological features is crucial for correctly modeling phenomena such as precipitation, river flow, and climate change.
# - **Inclusion of Specific Variables**: Variables like altitude, soil type, vegetation, and topographic characteristics can be fundamental in hydrology and climatology.
#
# #### Overfitting
#
# Overfitting occurs when the ML model performs well on training data but fails to generalize to test data.
#
# - Complex models, such as deep neural networks, tend to memorize the noise in the training data or even the data samples themselves if the dataset is small.
# - To mitigate overfitting:
#   - Select a model with fewer weights/parameters to limit predictive capacity to the strongest patterns.
#   - Collect more training data.
#   - Reduce noise in the training data by correcting errors and removing outliers.
#
# Mitigating overfitting is referred to as **regularization**. For example:
# - A linear regression model ($f(x) = ax + b$) has two degrees of freedom (2 parameters).
# - Restricting the flexibility of one parameter within a range reduces the degrees of freedom to 1–2, striking a balance between simplicity and pattern detection.
#
# Regularization is controlled using model hyperparameters, which define how the model learns. Specific considerations for streamflow and climate modeling include:
#
# - **Overfitting in Time Series**: Common due to the complexity of climate and hydrological patterns. Pay attention to model selection and regularization techniques.
# - **Climate and Hydrological Uncertainty**: Models must capture and quantify inherent uncertainty in these phenomena.
#
# #### Underfitting
#
# Underfitting is the opposite of overfitting. It occurs when the model is too simple to capture the underlying structure of the training data. Solutions include:
# - Selecting a more powerful model with more parameters.
# - Feeding better features to the algorithm (feature engineering).
# - Reducing restrictions on the model (lower regularization).
#
# #### Knowledge Transfer
#
# Knowledge transfer between regions or temporal scales is crucial in hydrology and climatology:
#
# - **Climate Model Transfer**: Adapting climate models trained in one region to another may require advanced techniques for adjustment and validation.
# - **Climate Extrapolation**: Predicting future climate behavior based on historical data is a significant challenge requiring robust modeling techniques.
#
# #### Climate Change Adaptation
#
# In the context of climate change, it is critical to:
#
# - **Incorporate Future Climate Scenarios**: Models must integrate climate projections to provide accurate predictions in changing conditions.
# - **Evaluate Hydrological Impacts**: Models should assess potential changes in precipitation and streamflow patterns and their effects on hydrological systems.

# %% [markdown]
# ### Testing and Validation
#
# Testing and validation of ML models are critical to ensuring their accuracy and reliability in predicting climatic and hydrological phenomena.
#
# We can evaluate our model by splitting the data into two sets: a **training set** and a **test set**. The main focus is on the **generalization error**, or out-of-sample error, which reflects the model's performance in a production environment.
#
# If the training error is low but the test error is high, this indicates that the model is overfitting. A common practice is to use **70%** of the data for training and the remaining **30%** for testing, although the exact proportion depends on the size of the dataset. For larger datasets, a smaller percentage can be used for testing. What about hydrology?
#
# When regularization parameters are tuned using the test set, the model risks overfitting to this set. To avoid this, a separate **validation set** is required for hyperparameter tuning. After tuning, the model is trained on the full training set (including the validation set) and evaluated on the test set.
#
# A simple yet computationally expensive solution for reserving a large validation set is to perform repeated cross-validation. However, this requires training the model N times. Both the validation and test sets must be as representative as possible of the data used in production. Is **K-fold cross-validation** a solution?
#
# ---
#
# ### Key Considerations
#
# #### Data Splitting
#
# For hydrology and climatology models, it is essential to carefully divide data into training and test sets. **Representative sets** must be selected, considering the wide variability in climatic and hydrological patterns across locations and time periods. Ensuring the training and test sets reflect real-world conditions for the region of interest is critical.
#
# #### Cross-Validation
#
# When data is limited and valuable, cross-validation provides a more robust evaluation of model performance. It helps address different conditions and locations, particularly in datasets with high spatial and temporal variability.
#
# #### Noise and Pattern Considerations
#
# Climatic and hydrological data are often affected by noise from seasonal fluctuations or extreme events. Models must capture relevant patterns while ignoring noise. Can signal decomposition techniques help?
#
# #### Model Assumptions
#
# Models are often based on specific assumptions about the relationships between variables. For example, linear regression assumes a linear relationship, which may not always reflect the complexity of climatic and hydrological phenomena.
